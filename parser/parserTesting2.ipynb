# %%
# coding: utf-8
import sys
import re
import string
import ast
from ast import AST
import tokenize
import token
from numbers import Number
import json
import io

# %%
def posFromText(text, textPos):
    snippet = text[:textPos+1]
    lines = snippet.split("\n")
    ln = len(lines)
    ch = len(lines[-1])
    return {'line': ln, 'ch': ch}

# %%
def regexEnd(text, start, parentEnd, nodeStart):
    endLineno = None
    endCh = None
    first = text[start]
    m = None
    
    if first in parens:
        # find outer parens
        outer = re.compile("\((.*)\)")
        m = outer.search(text[start:parentEnd+1])
    elif first in sqParens:
        # find outer parens
        outer = re.compile("\[(.*)\]")
        m = outer.search(text[start:parentEnd+1])
    elif first in brackets:
        # find outer parens
        outer = re.compile("\{(.*)\}")
        m = outer.search(text[start:parentEnd+1])
    else: return None
    
    lines = m.group(0).split("\n")
    end = len(m.group(0)) + start
    endLineno = nodeStart['line'] + len(lines)
    endCh = len(lines[-1]) - 1
    if (endLineno == nodeStart['line']): endCh += nodeStart['ch']
    myEnd = {'line': endLineno - 1, 'ch': endCh}
    return (end, myEnd,  m.group(0))

# %%
def findNodeStart(node):
    if hasattr(node, 'lineno'):
        return {'line': node.lineno, 'ch': node.col_offset}
    elif  type(node).__name__ == "Module":
        return {'line': 1, 'ch': 0}
    else: # must be some kind of wrapper node
        children = ast.iter_child_nodes(node)
        firstChild = next(children, None)
        if firstChild is None: return None
        return findNodeStart(firstChild)
        
        
def OLDfindNodeEnd(node, nextNode, text, start, end, nodeStart):
    endLineno = None
    endCh = None
    
    if(nextNode is None):
        bracketed = regexEnd(text, start, end, nodeStart)
        if(bracketed): return bracketed[0:2]
        else:
            pos = posFromText(text, end)
            return end, pos
    else:
        potentialEnd = findNodeStart(nextNode) #may need refinement
        print("NEXT NODE IS", nextNode, potentialEnd)
        snippet = text[start:end+1]
        lines = snippet.split("\n")
        ln = potentialEnd['line'] -  nodeStart['line']
        chars = start
        for x in lines[:ln+1]:
            chars += len(x) + 1 #add 1 for the \n
        chars -= 1 # remove the last \n
        return chars, potentialEnd

# %%
def findLiteralEnd(snippet, nodeStart): # what to do about multiline literal???
    bracketed = regexEnd(snippet, 0, len(snippet), nodeStart)
    if(bracketed):
        i, nodeEnd, punct = bracketed
        literal = [{'syntok': p} for p in list(punct)]
    else:
        end = 0
        for i, character in enumerate(snippet):
            if character in punctuation:
                end = i - 1
                break
        literal = snippet[0:end+1]
        ch = len(literal) + nodeStart['ch']
        line = nodeStart['line']
        nodeEnd = {'line': line, 'ch': ch}
        
    print("literal |"+str(literal)+"|")
    return (i, nodeEnd, literal)

# %%
def findNextChild(children, itr):
    banned = ["Store", "Load"]
    if(itr + 1 < len(children)):
        child = children[itr + 1]
        if(type(child).__name__ not in banned):
            return child, itr + 1
        else:
            return findNextChild(children, itr + 1)
    else:
        return None, itr + 1

# %%
def captureComment(text, textStart, textEnd):
    line = text[textStart:textEnd]
    line = line[:line.find("\n")]
    return textStart + len(line), line

# %%
'''
Call(expr func, expr* args, keyword* keywords)
'''
def visitCall(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    myStart = {'line': node.lineno, 'ch': node.col_offset}
    end = textStart
    end, value = visit(node.func, text, end, textEnd, None)
    myContent.append(value)
    end, symbols = getPunctuationBetween(text, end, textEnd, "(")
    myContent += symbols
    myContent.append({'syntok': '('})
    end += 1
    for argument in node.args:
        end, arg = visit(argument, text, end, textEnd, None)
        myContent.append(arg)
        # get any symbols like commas and spaces
        end, symbols = getPunctuationBetween(text, end, textEnd, ")")
        myContent += symbols
    for keyword in node.keywords:
        end, keyw = visit(keyword, text, end, textEnd, None)
        myContent.append(keyw)
        # get any symbols like commas and spaces
        end, symbols = getPunctuationBetween(text, end, textEnd, ")")
        myContent += symbols
    end, symbols = getPunctuationBetween(text, end - 1, textEnd, ")")
    myContent += symbols
    myContent.append({'syntok': ')'})
    end += 1
    myEnd = posFromText(text, end)
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", ast.dump(node, True, False), "\n",me,"\n")
    return end, me

# %%
def visitAttribute(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    end = textStart
    end, value = visit(node.value, text, textStart, textEnd, None)
    myContent.append(value)
    myContent.append({'syntok': '.'})
    attr = str(node.attr)
    myContent.append({'syntok': attr})
    myStart = value['start']
    myEnd = {'line': myStart['line'], 'ch': value['end']['ch'] + 1 + len(attr)}
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    end += 1 + len(attr)
    print("MADE:", end, ast.dump(node, True, False), "\n",me,"\n")
    return end, me

def visitSubscript(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    myStart = findNodeStart(node)
    end, value = visit(node.value, text, textStart, textEnd, None)
    end, slicey = visit(node.slice, text, end, textEnd, None)
    myContent.append(value)
    myContent.append(slicey)
    myEnd = slicey['end']
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", ast.dump(node, True, False), "\n",me,"\n")
    return end, me

# %%
'''
slice = Slice(expr? lower, expr? upper, expr? step)
          | ExtSlice(slice* dims)
          | Index(expr value)
'''
def visitIndex(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    myContent.append({'syntok': '['})
    end = textStart + 1
    print("Text is:", text[end:textEnd])
    end, symbols = getPunctuationBetween(text,end,textEnd)
    myContent += symbols
    end, value = visit(node.value, text, end, textEnd, None)
    myContent.append(value)
    end, symbols = getPunctuationBetween(text,end,textEnd, ']')
    myContent += symbols
    myContent.append({'syntok': ']'})
    end += 1
    
    myStart = {'line': value['start']['line'], 'ch': value['start']['ch'] - 1}
    myEnd = {'line': myStart['line'], 'ch': myStart['ch'] + 1 }
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", me,"\n")
    return end, me

# %%
'''
 -- keyword arguments supplied to call (NULL identifier for **kwargs)
    keyword = (identifier? arg, expr value)
'''
def visitKeyword(node, text, textStart, textEnd):
    print("TEXT IS:", text[textStart:textEnd+1])
    myType = type(node).__name__
    myContent = []
    myStart = posFromText(text, textStart)
    end = textStart
    if(node.arg): 
        arg = str(node.arg)
        myContent.append({'syntok':arg})
        end += len(arg)
        end, symbols = getPunctuationBetween(text,end,textEnd)
        myContent += symbols
    end, value = visit(node.value, text, end, textEnd, None)
    myContent.append(value)
    myEnd = value['end']
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", me,"\n")
    return end, me

# %%
def visit(node, text, textStart, textEnd, nextNode):
    
    # 1. first, figure out if we're dealing with a literal or parent
    children = list(ast.iter_child_nodes(node))
    
    # necissary to filter children using findNextChild, since there's some
    # metalabels like store or load we don't care about here
    child, child_itr = findNextChild(children, -1)
    print("\n",type(node).__name__, children, textStart, text[textStart])
    
    if not child: # LITERAL
        return visitLiteral(node, text, textStart)
    
    myType = type(node).__name__
    
    visitors = {"Attribute": visitAttribute,
                "Subscript": visitSubscript,
                "Index": visitIndex,
                "keyword": visitKeyword,
                "Call": visitCall}
    
    if myType in visitors:
        return visitors[myType](node, text, textStart, textEnd)
    else:
        print("NO VISITOR FOR "+myType)
        return genericVisit(node, text, textStart, textEnd, nextNode)
    
    
def visitLiteral(node, text, start):
    myType = type(node).__name__
    myStart = {'line': node.lineno, 'ch': node.col_offset}
    end, myEnd, myLiteral = findLiteralEnd(text[start:], myStart)
    end += start
    if(isinstance(myLiteral, str)):
        return (end, {'type': myType, 'start': myStart, 'end': myEnd, 'literal': myLiteral})
    else: # actually a list of syntok
        return (end, {'type': myType, 'start': myStart, 'end': myEnd, 'content': myLiteral})

# %%
def genericVisit(node, text, textStart, textEnd, nextNode):
    children = list(ast.iter_child_nodes(node))
    child, child_itr = findNextChild(children, -1)
    print(ast.dump(child, True, True))
    myType = type(node).__name__
    myContent = [] 
    myStart = findNodeStart(node)
    

    # now give each child a span of the text
    nextChild, child_itr = findNextChild(children, child_itr)
    i = textStart
    lineno = myStart['line']
    col_offset = myStart['ch']
    #print("text?", textEnd, textStart, lineno, col_offset)
    while i < textEnd and child:
        token = text[i]
        #if child: print(child, lineno, col_offset, child.lineno, child.col_offset, token)
        if child and (not hasattr(child, "lineno") or (lineno == child.lineno and col_offset == child.col_offset)):
            if not hasattr(child, "lineno"):
                print("CHILD HAS NO POS:"+str(i), text[199], text[200], text[201:213], token)
                # child has no start loc
                i, symbols = getPunctuationBetween(text, i, textEnd)
                print(i, symbols)
                myContent += symbols
            print(myType," BEFORE: ", myContent)
            new_i, childContent = visit(child, text, i, textEnd, nextChild)
            myContent.append(childContent)
            col_offset += (new_i - i) - 1
            i = new_i - 1
            print(myType," AFTER: ",myContent, i, "\n")
            child = nextChild
            nextChild, child_itr = findNextChild(children, child_itr)
        elif token == "#":
            new_i, comment = captureComment(text, i, textEnd)
            myContent.append({'syntok': comment})
            print("COMMENT?", comment, new_i, "|"+text[new_i]+"|")
            i = new_i - 1
        elif token in newline:
            myContent.append({'syntok': token})
            lineno += 1
            col_offset = -1
            if not child: textEnd = i #end of this node actually
        else:
            myContent.append({'syntok':token})
        i += 1
        col_offset += 1
    
    
    #okay, all children processed. now need to figure out the end
    myEnd = posFromText(text, i)

    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    return i, me

# %%
def getPunctuationBetween(text, textStart, textEnd, stopChar = ""):
    i = textStart
    char = text[textStart]
    content = []
    while i < textEnd and char in punctuation and char != stopChar:
        content.append({"syntok": char})
        i += 1
        char = text[i]
        
    return i, content

def getRemainder(text, textStart, stopChar):
    #check if node is allowed remainder text
    if stopChar is None: return []
    i = textStart
    char = text[textStart]
    
    #check if end is already reached
    if(char == stopChar): return  []
    else: 
        i += 1
        char = text[i]
    
    content = []
    while i < len(text) and char != stopChar:
        content.append({"syntok": char})
        i += 1
        char = text[i]
    if(i < len(text)):
        print("FINALE", text[i])
        content.append({"syntok": char})
        
    return content

# %%
def parse(text):
    node = ast.parse(text)
    print(ast.dump(node, True, True))
    print("\n",visit(node, text, 0, len(text), None))

# %%
text = """# TODO: Select three indices of your choice you wish to sample from the dataset
indices = []

# Create a DataFrame of the chosen samples
samples = pd.DataFrame(data.loc[indices], columns = data.keys()).reset_index(drop = True)
print("Chosen samples of wholesale customers dataset:")
display(samples)"""


sqParens = set(["[","]"])
parens = set(["(",")"])
brackets = set(["{","}"])
spaces = set(["\t", " "])
newline = set(["\n"]) #todo may vary across platforms
punctuation = set(string.punctuation)
punctuation.add(" ")


# to hurry up, reduce ast at this stage?
# match parens [] {} () otherwise those can end up in weird places

parse(text)
#print(json.dumps(main(l, tree),  indent=2))
# Out:
# Module(body=[Assign(targets=[Name(id='indices', ctx=Store(), lineno=2, col_offset=0)], value=List(elts=[], ctx=Load(), lineno=2, col_offset=10), lineno=2, col_offset=0), Assign(targets=[Name(id='samples', ctx=Store(), lineno=5, col_offset=0)], value=Call(func=Attribute(value=Call(func=Attribute(value=Name(id='pd', ctx=Load(), lineno=5, col_offset=10), attr='DataFrame', ctx=Load(), lineno=5, col_offset=10), args=[Subscript(value=Attribute(value=Name(id='data', ctx=Load(), lineno=5, col_offset=23), attr='loc', ctx=Load(), lineno=5, col_offset=23), slice=Index(value=Name(id='indices', ctx=Load(), lineno=5, col_offset=32)), ctx=Load(), lineno=5, col_offset=23)], keywords=[keyword(arg='columns', value=Call(func=Attribute(value=Name(id='data', ctx=Load(), lineno=5, col_offset=52), attr='keys', ctx=Load(), lineno=5, col_offset=52), args=[], keywords=[], lineno=5, col_offset=52))], lineno=5, col_offset=10), attr='reset_index', ctx=Load(), lineno=5, col_offset=10), args=[], keywords=[keyword(arg='drop', value=NameConstant(value=True, lineno=5, col_offset=84))], lineno=5, col_offset=10), lineno=5, col_offset=0), Expr(value=Call(func=Name(id='print', ctx=Load(), lineno=6, col_offset=0), args=[Str(s='Chosen samples of wholesale customers dataset:', lineno=6, col_offset=6)], keywords=[], lineno=6, col_offset=0), lineno=6, col_offset=0), Expr(value=Call(func=Name(id='display', ctx=Load(), lineno=7, col_offset=0), args=[Name(id='samples', ctx=Load(), lineno=7, col_offset=8)], keywords=[], lineno=7, col_offset=0), lineno=7, col_offset=0)])
#
#  Module [<_ast.Assign object at 0x10e1be160>, <_ast.Assign object at 0x10e1bef60>, <_ast.Expr object at 0x10deb6b00>, <_ast.Expr object at 0x10df052e8>] 0 #
# NO VISITOR FOR Module
# Assign(targets=[Name(id='indices', ctx=Store(), lineno=2, col_offset=0)], value=List(elts=[], ctx=Load(), lineno=2, col_offset=10), lineno=2, col_offset=0)
# COMMENT? # TODO: Select three indices of your choice you wish to sample from the dataset 79 |
# |
# Module  BEFORE:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}]
#
#  Assign [<_ast.Name object at 0x10e1beac8>, <_ast.List object at 0x10e1be470>] 80 i
# NO VISITOR FOR Assign
# Name(id='indices', ctx=Store(), lineno=2, col_offset=0)
# Assign  BEFORE:  []
#
#  Name [<_ast.Store object at 0x10bcad9b0>] 80 i
# literal |indices|
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}] 86
#
# Assign  BEFORE:  [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}]
#
#  List [<_ast.Load object at 0x10bcad898>] 90 [
# literal |[{'syntok': '['}, {'syntok': ']'}]|
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}] 91
#
# Module  AFTER:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}] 91
#
# COMMENT? # Create a DataFrame of the chosen samples 136 |
# |
# Module  BEFORE:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}]
#
#  Assign [<_ast.Name object at 0x10e1be0f0>, <_ast.Call object at 0x10e1bebe0>] 137 s
# NO VISITOR FOR Assign
# Name(id='samples', ctx=Store(), lineno=5, col_offset=0)
# Assign  BEFORE:  []
#
#  Name [<_ast.Store object at 0x10bcad9b0>] 137 s
# literal |samples|
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}] 143
#
# Assign  BEFORE:  [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}]
#
#  Call [<_ast.Attribute object at 0x10e1be828>, <_ast.keyword object at 0x10deb6630>] 147 p
#
#  Attribute [<_ast.Call object at 0x10e1beb00>, <_ast.Load object at 0x10bcad898>] 147 p
#
#  Call [<_ast.Attribute object at 0x10e1bec88>, <_ast.Subscript object at 0x10e1beb70>, <_ast.keyword object at 0x10e1be128>] 147 p
#
#  Attribute [<_ast.Name object at 0x10e1beda0>, <_ast.Load object at 0x10bcad898>] 147 p
#
#  Name [<_ast.Load object at 0x10bcad898>] 147 p
# literal |pd|
# MADE: 159 Attribute(value=Name(id='pd', ctx=Load()), attr='DataFrame', ctx=Load())
#  {'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}
#
#
#  Subscript [<_ast.Attribute object at 0x10e1bef28>, <_ast.Index object at 0x10e1be780>, <_ast.Load object at 0x10bcad898>] 160 d
#
#  Attribute [<_ast.Name object at 0x10e1bec18>, <_ast.Load object at 0x10bcad898>] 160 d
#
#  Name [<_ast.Load object at 0x10bcad898>] 160 d
# literal |data|
# MADE: 168 Attribute(value=Name(id='data', ctx=Load()), attr='loc', ctx=Load())
#  {'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}
#
#
#  Index [<_ast.Name object at 0x10e1be5c0>] 168 [
# Text is: indices], columns = data.keys()).reset_index(drop = True)
# print("Chosen samples of wholesale customers dataset:")
# display(samples)
#
#  Name [<_ast.Load object at 0x10bcad898>] 169 i
# literal |indices|
# MADE: {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}
#
# MADE: Subscript(value=Attribute(value=Name(id='data', ctx=Load()), attr='loc', ctx=Load()), slice=Index(value=Name(id='indices', ctx=Load())), ctx=Load())
#  {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}
#
#
#  keyword [<_ast.Call object at 0x10e1be358>] 179 c
# TEXT IS: columns = data.keys()).reset_index(drop = True)
# print("Chosen samples of wholesale customers dataset:")
# display(samples)
#
#  Call [<_ast.Attribute object at 0x10e1bee10>] 189 d
#
#  Attribute [<_ast.Name object at 0x10deb6710>, <_ast.Load object at 0x10bcad898>] 189 d
#
#  Name [<_ast.Load object at 0x10bcad898>] 189 d
# literal |data|
# MADE: 198 Attribute(value=Name(id='data', ctx=Load()), attr='keys', ctx=Load())
#  {'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}
#
# MADE: Call(func=Attribute(value=Name(id='data', ctx=Load()), attr='keys', ctx=Load()), args=[], keywords=[])
#  {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}
#
# MADE: {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}
#
# MADE: Call(func=Attribute(value=Name(id='pd', ctx=Load()), attr='DataFrame', ctx=Load()), args=[Subscript(value=Attribute(value=Name(id='data', ctx=Load()), attr='loc', ctx=Load()), slice=Index(value=Name(id='indices', ctx=Load())), ctx=Load())], keywords=[keyword(arg='columns', value=Call(func=Attribute(value=Name(id='data', ctx=Load()), attr='keys', ctx=Load()), args=[], keywords=[]))])
#  {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}
#
# MADE: 212 Attribute(value=Call(func=Attribute(value=Name(id='pd', ctx=Load()), attr='DataFrame', ctx=Load()), args=[Subscript(value=Attribute(value=Name(id='data', ctx=Load()), attr='loc', ctx=Load()), slice=Index(value=Name(id='indices', ctx=Load())), ctx=Load())], keywords=[keyword(arg='columns', value=Call(func=Attribute(value=Name(id='data', ctx=Load()), attr='keys', ctx=Load()), args=[], keywords=[]))]), attr='reset_index', ctx=Load())
#  {'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}
#
#
#  keyword [<_ast.NameConstant object at 0x10deb6ac8>] 213 (
# TEXT IS: (drop = True)
# print("Chosen samples of wholesale customers dataset:")
# display(samples)
#
#  NameConstant [] 217 p
# literal |p|
# MADE: {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}
#
# MADE: Call(func=Attribute(value=Call(func=Attribute(value=Name(id='pd', ctx=Load()), attr='DataFrame', ctx=Load()), args=[Subscript(value=Attribute(value=Name(id='data', ctx=Load()), attr='loc', ctx=Load()), slice=Index(value=Name(id='indices', ctx=Load())), ctx=Load())], keywords=[keyword(arg='columns', value=Call(func=Attribute(value=Name(id='data', ctx=Load()), attr='keys', ctx=Load()), args=[], keywords=[]))]), attr='reset_index', ctx=Load()), args=[], keywords=[keyword(arg='drop', value=NameConstant(value=True))])
#  {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}
#
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}] 221
#
# Module  AFTER:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}]}] 221
#
# Module  BEFORE:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}]}, {'syntok': 'r'}, {'syntok': 'u'}, {'syntok': 'e'}, {'syntok': ')'}, {'syntok': '\n'}]
#
#  Expr [<_ast.Call object at 0x10deb60b8>] 227 p
# NO VISITOR FOR Expr
# Call(func=Name(id='print', ctx=Load(), lineno=6, col_offset=0), args=[Str(s='Chosen samples of wholesale customers dataset:', lineno=6, col_offset=6)], keywords=[], lineno=6, col_offset=0)
# Expr  BEFORE:  []
#
#  Call [<_ast.Name object at 0x10deb6e80>, <_ast.Str object at 0x10df05c88>] 227 p
#
#  Name [<_ast.Load object at 0x10bcad898>] 227 p
# literal |print|
#
#  Str [] 233 "
# literal ||
# MADE: Call(func=Name(id='print', ctx=Load()), args=[Str(s='Chosen samples of wholesale customers dataset:')], keywords=[])
#  {'type': 'Call', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Name', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 5}, 'literal': 'print'}, {'syntok': '('}, {'type': 'Str', 'start': {'line': 6, 'ch': 6}, 'end': {'line': 6, 'ch': 6}, 'literal': ''}, {'syntok': '"'}, {'syntok': '"'}, {'syntok': ')'}]}
#
# Expr  AFTER:  [{'type': 'Call', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Name', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 5}, 'literal': 'print'}, {'syntok': '('}, {'type': 'Str', 'start': {'line': 6, 'ch': 6}, 'end': {'line': 6, 'ch': 6}, 'literal': ''}, {'syntok': '"'}, {'syntok': '"'}, {'syntok': ')'}]}] 234
#
# Module  AFTER:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}]}, {'syntok': 'r'}, {'syntok': 'u'}, {'syntok': 'e'}, {'syntok': ')'}, {'syntok': '\n'}, {'type': 'Expr', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Call', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Name', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 5}, 'literal': 'print'}, {'syntok': '('}, {'type': 'Str', 'start': {'line': 6, 'ch': 6}, 'end': {'line': 6, 'ch': 6}, 'literal': ''}, {'syntok': '"'}, {'syntok': '"'}, {'syntok': ')'}]}]}] 234
#
# Module  BEFORE:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}]}, {'syntok': 'r'}, {'syntok': 'u'}, {'syntok': 'e'}, {'syntok': ')'}, {'syntok': '\n'}, {'type': 'Expr', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Call', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Name', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 5}, 'literal': 'print'}, {'syntok': '('}, {'type': 'Str', 'start': {'line': 6, 'ch': 6}, 'end': {'line': 6, 'ch': 6}, 'literal': ''}, {'syntok': '"'}, {'syntok': '"'}, {'syntok': ')'}]}]}, {'syntok': 'h'}, {'syntok': 'o'}, {'syntok': 's'}, {'syntok': 'e'}, {'syntok': 'n'}, {'syntok': ' '}, {'syntok': 's'}, {'syntok': 'a'}, {'syntok': 'm'}, {'syntok': 'p'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': 's'}, {'syntok': ' '}, {'syntok': 'o'}, {'syntok': 'f'}, {'syntok': ' '}, {'syntok': 'w'}, {'syntok': 'h'}, {'syntok': 'o'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': 's'}, {'syntok': 'a'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': ' '}, {'syntok': 'c'}, {'syntok': 'u'}, {'syntok': 's'}, {'syntok': 't'}, {'syntok': 'o'}, {'syntok ...
#
#  Expr [<_ast.Call object at 0x10df055f8>] 283 d
# NO VISITOR FOR Expr
# Call(func=Name(id='display', ctx=Load(), lineno=7, col_offset=0), args=[Name(id='samples', ctx=Load(), lineno=7, col_offset=8)], keywords=[], lineno=7, col_offset=0)
# Expr  BEFORE:  []
#
#  Call [<_ast.Name object at 0x10de247f0>, <_ast.Name object at 0x10e0eacc0>] 283 d
#
#  Name [<_ast.Load object at 0x10bcad898>] 283 d
# literal |display|
#
#  Name [<_ast.Load object at 0x10bcad898>] 291 s
# literal |samples|
# MADE: Call(func=Name(id='display', ctx=Load()), args=[Name(id='samples', ctx=Load())], keywords=[])
#  {'type': 'Call', 'start': {'line': 7, 'ch': 0}, 'end': {'line': 7, 'ch': 16}, 'content': [{'type': 'Name', 'start': {'line': 7, 'ch': 0}, 'end': {'line': 7, 'ch': 7}, 'literal': 'display'}, {'syntok': '('}, {'type': 'Name', 'start': {'line': 7, 'ch': 8}, 'end': {'line': 7, 'ch': 15}, 'literal': 'samples'}, {'syntok': ')'}]}
#
# Expr  AFTER:  [{'type': 'Call', 'start': {'line': 7, 'ch': 0}, 'end': {'line': 7, 'ch': 16}, 'content': [{'type': 'Name', 'start': {'line': 7, 'ch': 0}, 'end': {'line': 7, 'ch': 7}, 'literal': 'display'}, {'syntok': '('}, {'type': 'Name', 'start': {'line': 7, 'ch': 8}, 'end': {'line': 7, 'ch': 15}, 'literal': 'samples'}, {'syntok': ')'}]}] 297
#
# Module  AFTER:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}]}, {'syntok': 'r'}, {'syntok': 'u'}, {'syntok': 'e'}, {'syntok': ')'}, {'syntok': '\n'}, {'type': 'Expr', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Call', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Name', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 5}, 'literal': 'print'}, {'syntok': '('}, {'type': 'Str', 'start': {'line': 6, 'ch': 6}, 'end': {'line': 6, 'ch': 6}, 'literal': ''}, {'syntok': '"'}, {'syntok': '"'}, {'syntok': ')'}]}]}, {'syntok': 'h'}, {'syntok': 'o'}, {'syntok': 's'}, {'syntok': 'e'}, {'syntok': 'n'}, {'syntok': ' '}, {'syntok': 's'}, {'syntok': 'a'}, {'syntok': 'm'}, {'syntok': 'p'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': 's'}, {'syntok': ' '}, {'syntok': 'o'}, {'syntok': 'f'}, {'syntok': ' '}, {'syntok': 'w'}, {'syntok': 'h'}, {'syntok': 'o'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': 's'}, {'syntok': 'a'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': ' '}, {'syntok': 'c'}, {'syntok': 'u'}, {'syntok': 's'}, {'syntok': 't'}, {'syntok': 'o'}, {'syntok' ...
#
#
#  (298, {'type': 'Module', 'start': {'line': 1, 'ch': 0}, 'end': {'line': 7, 'ch': 16}, 'content': [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 3, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 86}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 76}, 'content': [{'type': 'Call', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 22}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 31}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}, {'type': 'keyword', 'start': {'line': 5, 'ch': 43}, 'end': {'line': 5, 'ch': 64}, 'content': [{'syntok': 'columns'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'Call', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 64}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 61}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 52}, 'end': {'line': 5, 'ch': 56}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'keys'}]}, {'syntok': '('}, {'syntok': '('}, {'syntok': ')'}]}]}, {'syntok': ')'}]}, {'syntok': '.'}, {'syntok': 'reset_index'}]}, {'syntok': '('}, {'type': 'keyword', 'start': {'line': 5, 'ch': 77}, 'end': {'line': 5, 'ch': 85}, 'content': [{'syntok': 'drop'}, {'type': 'NameConstant', 'start': {'line': 5, 'ch': 84}, 'end': {'line': 5, 'ch': 85}, 'literal': 'p'}]}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'syntok': ' '}, {'syntok': ')'}]}]}, {'syntok': 'r'}, {'syntok': 'u'}, {'syntok': 'e'}, {'syntok': ')'}, {'syntok': '\n'}, {'type': 'Expr', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Call', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 9}, 'content': [{'type': 'Name', 'start': {'line': 6, 'ch': 0}, 'end': {'line': 6, 'ch': 5}, 'literal': 'print'}, {'syntok': '('}, {'type': 'Str', 'start': {'line': 6, 'ch': 6}, 'end': {'line': 6, 'ch': 6}, 'literal': ''}, {'syntok': '"'}, {'syntok': '"'}, {'syntok': ')'}]}]}, {'syntok': 'h'}, {'syntok': 'o'}, {'syntok': 's'}, {'syntok': 'e'}, {'syntok': 'n'}, {'syntok': ' '}, {'syntok': 's'}, {'syntok': 'a'}, {'syntok': 'm'}, {'syntok': 'p'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': 's'}, {'syntok': ' '}, {'syntok': 'o'}, {'syntok': 'f'}, {'syntok': ' '}, {'syntok': 'w'}, {'syntok': 'h'}, {'syntok': 'o'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': 's'}, {'syntok': 'a'}, {'syntok': 'l'}, {'syntok': 'e'}, {'syntok': ' '}, {'syntok': ' ...
