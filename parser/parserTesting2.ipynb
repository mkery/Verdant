# %%
# coding: utf-8
import sys
import re
import string
import ast
from ast import AST
import tokenize
import token
from numbers import Number
import json
import io

# %%
def regexEnd(text, start, parentEnd, nodeStart):
    endLineno = None
    endCh = None
    first = text[start]
    m = None
    
    if first in parens:
        # find outer parens
        outer = re.compile("\((.*)\)")
        m = outer.search(text[start:parentEnd+1])
    elif first in sqParens:
        # find outer parens
        outer = re.compile("\[(.*)\]")
        m = outer.search(text[start:parentEnd+1])
    elif first in brackets:
        # find outer parens
        outer = re.compile("\{(.*)\}")
        m = outer.search(text[start:parentEnd+1])
    else: return None
    
    lines = m.group(0).split("\n")
    end = len(m.group(0)) + start
    endLineno = nodeStart['line'] + len(lines)
    endCh = len(lines[-1]) - 1
    if (endLineno == nodeStart['line']): endCh += nodeStart['ch']
    myEnd = {'line': endLineno - 1, 'ch': endCh}
    return (end, myEnd,  m.group(0))

# %%
def findNodeStart(node):
    if hasattr(node, 'lineno'):
        return {'line': node.lineno, 'ch': node.col_offset}
    elif  type(node).__name__ == "Module":
        return {'line': 1, 'ch': 0}
    else: # must be some kind of wrapper node
        children = ast.iter_child_nodes(node)
        firstChild = next(children, None)
        if firstChild is None: return None
        return findNodeStart(firstChild)
        
        
def findNodeEnd(node, nextNode, text, start, end, nodeStart):
    endLineno = None
    endCh = None
    
    if(nextNode is None):
        bracketed = regexEnd(text, start, end, nodeStart)
        if(bracketed): return bracketed[0:2]
        else:
            snippet = text[start:end+1]
            lines = snippet.split("\n")
            ln = nodeStart['line'] + len(lines) - 1
            ch = len(lines[-1]) - 1
            if (ln == nodeStart['line']): ch += nodeStart['ch']
            return end, {'line': ln, 'ch': ch}
    else:
        potentialEnd = findNodeStart(nextNode) #may need refinement
        snippet = text[start:end+1]
        lines = snippet.split("\n")
        ln = potentialEnd['line'] -  nodeStart['line']
        chars = start
        for x in lines[:ln+1]:
            chars += len(x) + 1 #add 1 for the \n
        chars -= 1 # remove the last \n
        return chars, potentialEnd

# %%
def findLiteralEnd(snippet, nodeStart): # what to do about multiline literal???
    bracketed = regexEnd(snippet, 0, len(snippet), nodeStart)
    if(bracketed):
        i, nodeEnd, punct = bracketed
        literal = [{'syntok': p} for p in list(punct)]
    else:
        end = 0
        for i, character in enumerate(snippet):
            if character in punctuation:
                end = i - 1
                break
        literal = snippet[0:end+1]
        ch = len(literal) + nodeStart['ch']
        line = nodeStart['line']
        nodeEnd = {'line': line, 'ch': ch}
        
    print("literal |"+str(literal)+"|")
    return (i, nodeEnd, literal)

# %%
def findNextChild(children, itr):
    banned = ["Store", "Load"]
    if(itr + 1 < len(children)):
        child = children[itr + 1]
        if(type(child).__name__ not in banned):
            return child, itr + 1
        else:
            return findNextChild(children, itr + 1)
    else:
        return None, itr + 1

# %%
def captureComment(text, textStart, textEnd):
    line = text[textStart:textEnd]
    line = line[:line.find("\n")]
    return textStart + len(line), line

# %%
def visitAttribute(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    end, value = visit(node.value, text, textStart, textEnd, None)
    myContent.append(value)
    myContent.append({'syntok': '.'})
    attr = str(node.attr)
    myContent.append({'syntok': attr})
    myStart = value['start']
    myEnd = {'line': myStart['line'], 'ch': myStart['ch'] + 1 + len(attr)}
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    end += 1 + len(attr)
    print("END IS:", end, textStart)
    print("MADE:", me,"\n")
    return end, me

def visitSubscript(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    myStart = findNodeStart(node)
    end, value = visit(node.value, text, textStart, textEnd, None)
    end, slicey = visit(node.slice, text, end, textEnd, None)
    myContent.append(value)
    myContent.append(slicey)
    myEnd = slicey['end']
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", me,"\n")
    return end, me

# %%
'''
slice = Slice(expr? lower, expr? upper, expr? step)
          | ExtSlice(slice* dims)
          | Index(expr value)
'''
def visitIndex(node, text, textStart, textEnd):
    myType = type(node).__name__
    myContent = []
    myContent.append({'syntok': '['})
    end = textStart + 1
    print("Text is:", text[end:textEnd])
    end, symbols = getPunctuationBetween(text,end,textEnd)
    myContent += symbols
    end, value = visit(node.value, text, end, textEnd, None)
    myContent.append(value)
    end, symbols = getPunctuationBetween(text,end,textEnd, ']')
    myContent += symbols
    myContent.append({'syntok': ']'})
    end += 1
    
    myStart = {'line': value['start']['line'], 'ch': value['start']['ch'] - 1}
    myEnd = {'line': myStart['line'], 'ch': myStart['ch'] + 1 }
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", me,"\n")
    return end, me

# %%
'''
 -- keyword arguments supplied to call (NULL identifier for **kwargs)
    keyword = (identifier? arg, expr value)
'''
def visitKeyword(node, text, textStart, textEnd):
    print("TEXT IS:", text[textStart:textEnd+1])
    myType = type(node).__name__
    myContent = []
    end, arg = visit(node.arg, text, textStart, textEnd, None)
    if(arg): 
        myContent.append(arg)
        end, symbols = getPunctuationBetween(text,end,textEnd)
        myContent += symbols
    end, value = visit(node.value, text, textStart, textEnd, None)
    myContent.append(value)
    if(arg): myStart = arg['start']
    else: myStart = value['start']
    myEnd = value['end']
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    print("MADE:", me,"\n")
    return end, me

# %%
def visit(node, text, textStart, textEnd, nextNode):
    
    # 1. first, figure out if we're dealing with a literal or parent
    children = list(ast.iter_child_nodes(node))
    
    # necissary to filter children using findNextChild, since there's some
    # metalabels like store or load we don't care about here
    child, child_itr = findNextChild(children, -1)
    print("\n",type(node).__name__, children)
    
    if not child: # LITERAL
        return visitLiteral(node, text, textStart)
    
    myType = type(node).__name__
    
    visitors = {"Attribute": visitAttribute,
                "Subscript": visitSubscript,
                "Index": visitIndex,
                "keyword": visitKeyword}
    
    if myType in visitors:
        return visitors[myType](node, text, textStart, textEnd)
    else:
        print("NO VISITOR FOR "+myType)
        return genericVisit(node, text, textStart, textEnd, nextNode)
    
    
def visitLiteral(node, text, start):
    myType = type(node).__name__
    myStart = {'line': node.lineno, 'ch': node.col_offset}
    end, myEnd, myLiteral = findLiteralEnd(text[start:], myStart)
    end += start
    if(isinstance(myLiteral, str)):
        return (end, {'type': myType, 'start': myStart, 'end': myEnd, 'literal': myLiteral})
    else: # actually a list of syntok
        return (end, {'type': myType, 'start': myStart, 'end': myEnd, 'content': myLiteral})

# %%
def genericVisit(node, text, textStart, textEnd, nextNode):
    children = list(ast.iter_child_nodes(node))
    child, child_itr = findNextChild(children, -1)
    print(ast.dump(child, True, True))
    myType = type(node).__name__
    myContent = [] 
    myStart = findNodeStart(node)
    textEnd, myEnd = findNodeEnd(node, nextNode, text, textStart, textEnd, myStart)
    
    print("POSITION:", myStart, myEnd)

    # now give each child a span of the text
    nextChild, child_itr = findNextChild(children, child_itr)
    i = textStart
    lineno = myStart['line']
    col_offset = myStart['ch']
    #print("text?", textEnd, textStart, lineno, col_offset)
    while i < textEnd:
        token = text[i]
        #if child: print(child, lineno, col_offset, child.lineno, child.col_offset, token)
        if child and (not hasattr(child, "lineno") or (lineno == child.lineno and col_offset == child.col_offset)):
            if not hasattr(child, "lineno"):
               # child has no start loc
               i, symbols = getPunctuationBetween(text, i, textEnd)
               myContent += symbols
            print(myType," BEFORE: ", myContent)
            new_i, childContent = visit(child, text, i, textEnd, nextChild)
            myContent.append(childContent)
            col_offset += (new_i - i) - 1
            i = new_i - 1
            print(myType," AFTER: ",myContent, i, "\n")
            child = nextChild
            nextChild, child_itr = findNextChild(children, child_itr)
        elif token == "#":
            new_i, comment = captureComment(text, i, textEnd)
            myContent.append({'syntok': comment})
            print("COMMENT?", comment, new_i, "|"+text[new_i]+"|")
            i = new_i - 1
        elif token in newline:
            myContent.append({'syntok': token})
            lineno += 1
            col_offset = -1
            if not child: textEnd = i #end of this node actually
        else:
            myContent.append({'syntok':token})
        i += 1
        col_offset += 1
    
    me = {'type': myType, 'start': myStart, 'end': myEnd, 'content': myContent}
    return textEnd, me

# %%
def getPunctuationBetween(text, textStart, textEnd, stopChar = ""):
    i = textStart
    char = text[textStart]
    content = []
    while i < textEnd and char in punctuation and char != stopChar:
        content.append({"syntok": char})
        i += 1
        char = text[i]
        
    return i, content

# %%
def parse(text):
    node = ast.parse(text)
    print(ast.dump(node, True, True))
    print("\n",visit(node, text, 0, len(text), None))

# %%
text = """# TODO: Select three indices of your choice you wish to sample from the dataset
indices = []

# Create a DataFrame of the chosen samples
samples = pd.DataFrame(data.loc[indices], columns = data.keys()).reset_index(drop = True)
print("Chosen samples of wholesale customers dataset:")
display(samples)"""


sqParens = set(["[","]"])
parens = set(["(",")"])
brackets = set(["{","}"])
newline = set(["\n"]) #todo may vary across platforms
punctuation = set(string.punctuation)
punctuation.add(" ")


# to hurry up, reduce ast at this stage?
# match parens [] {} () otherwise those can end up in weird places

parse(text)
#print(json.dumps(main(l, tree),  indent=2))
# Out:
# Module(body=[Assign(targets=[Name(id='indices', ctx=Store(), lineno=2, col_offset=0)], value=List(elts=[], ctx=Load(), lineno=2, col_offset=10), lineno=2, col_offset=0), Assign(targets=[Name(id='samples', ctx=Store(), lineno=5, col_offset=0)], value=Call(func=Attribute(value=Call(func=Attribute(value=Name(id='pd', ctx=Load(), lineno=5, col_offset=10), attr='DataFrame', ctx=Load(), lineno=5, col_offset=10), args=[Subscript(value=Attribute(value=Name(id='data', ctx=Load(), lineno=5, col_offset=23), attr='loc', ctx=Load(), lineno=5, col_offset=23), slice=Index(value=Name(id='indices', ctx=Load(), lineno=5, col_offset=32)), ctx=Load(), lineno=5, col_offset=23)], keywords=[keyword(arg='columns', value=Call(func=Attribute(value=Name(id='data', ctx=Load(), lineno=5, col_offset=52), attr='keys', ctx=Load(), lineno=5, col_offset=52), args=[], keywords=[], lineno=5, col_offset=52))], lineno=5, col_offset=10), attr='reset_index', ctx=Load(), lineno=5, col_offset=10), args=[], keywords=[keyword(arg='drop', value=NameConstant(value=True, lineno=5, col_offset=84))], lineno=5, col_offset=10), lineno=5, col_offset=0), Expr(value=Call(func=Name(id='print', ctx=Load(), lineno=6, col_offset=0), args=[Str(s='Chosen samples of wholesale customers dataset:', lineno=6, col_offset=6)], keywords=[], lineno=6, col_offset=0), lineno=6, col_offset=0), Expr(value=Call(func=Name(id='display', ctx=Load(), lineno=7, col_offset=0), args=[Name(id='samples', ctx=Load(), lineno=7, col_offset=8)], keywords=[], lineno=7, col_offset=0), lineno=7, col_offset=0)])
#
#  Module [<_ast.Assign object at 0x10d8f3a58>, <_ast.Assign object at 0x10d8f3ba8>, <_ast.Expr object at 0x10d9ca748>, <_ast.Expr object at 0x10d9cae48>]
# NO VISITOR FOR Module
# Assign(targets=[Name(id='indices', ctx=Store(), lineno=2, col_offset=0)], value=List(elts=[], ctx=Load(), lineno=2, col_offset=10), lineno=2, col_offset=0)
# POSITION: {'line': 1, 'ch': 0} {'line': 7, 'ch': 15}
# COMMENT? # TODO: Select three indices of your choice you wish to sample from the dataset 79 |
# |
# Module  BEFORE:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}]
#
#  Assign [<_ast.Name object at 0x10d8f3780>, <_ast.List object at 0x10d8f3e80>]
# NO VISITOR FOR Assign
# Name(id='indices', ctx=Store(), lineno=2, col_offset=0)
# POSITION: {'line': 2, 'ch': 0} {'line': 5, 'ch': 0}
# Assign  BEFORE:  []
#
#  Name [<_ast.Store object at 0x10bcad9b0>]
# literal |indices|
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}] 86
#
# Assign  BEFORE:  [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}]
#
#  List [<_ast.Load object at 0x10bcad898>]
# literal |[{'syntok': '['}, {'syntok': ']'}]|
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}] 91
#
# Module  AFTER:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 5, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}, {'syntok': '\n'}]}] 91
#
# COMMENT? # Create a DataFrame of the chosen samples 136 |
# |
# Module  BEFORE:  [{'syntok': '# TODO: Select three indices of your choice you wish to sample from the dataset'}, {'syntok': '\n'}, {'type': 'Assign', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 5, 'ch': 0}, 'content': [{'type': 'Name', 'start': {'line': 2, 'ch': 0}, 'end': {'line': 2, 'ch': 7}, 'literal': 'indices'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}, {'type': 'List', 'start': {'line': 2, 'ch': 10}, 'end': {'line': 2, 'ch': 1}, 'content': [{'syntok': '['}, {'syntok': ']'}]}, {'syntok': '\n'}]}, {'syntok': '\n'}, {'syntok': '\n'}, {'syntok': '# Create a DataFrame of the chosen samples'}, {'syntok': '\n'}]
#
#  Assign [<_ast.Name object at 0x10d8f3518>, <_ast.Call object at 0x10d9cab38>]
# NO VISITOR FOR Assign
# Name(id='samples', ctx=Store(), lineno=5, col_offset=0)
# POSITION: {'line': 5, 'ch': 0} {'line': 6, 'ch': 0}
# Assign  BEFORE:  []
#
#  Name [<_ast.Store object at 0x10bcad9b0>]
# literal |samples|
# Assign  AFTER:  [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}] 143
#
# Assign  BEFORE:  [{'type': 'Name', 'start': {'line': 5, 'ch': 0}, 'end': {'line': 5, 'ch': 7}, 'literal': 'samples'}, {'syntok': ' '}, {'syntok': '='}, {'syntok': ' '}]
#
#  Call [<_ast.Attribute object at 0x10d9ca6d8>, <_ast.keyword object at 0x10d9ca048>]
# NO VISITOR FOR Call
# Attribute(value=Call(func=Attribute(value=Name(id='pd', ctx=Load(), lineno=5, col_offset=10), attr='DataFrame', ctx=Load(), lineno=5, col_offset=10), args=[Subscript(value=Attribute(value=Name(id='data', ctx=Load(), lineno=5, col_offset=23), attr='loc', ctx=Load(), lineno=5, col_offset=23), slice=Index(value=Name(id='indices', ctx=Load(), lineno=5, col_offset=32)), ctx=Load(), lineno=5, col_offset=23)], keywords=[keyword(arg='columns', value=Call(func=Attribute(value=Name(id='data', ctx=Load(), lineno=5, col_offset=52), attr='keys', ctx=Load(), lineno=5, col_offset=52), args=[], keywords=[], lineno=5, col_offset=52))], lineno=5, col_offset=10), attr='reset_index', ctx=Load(), lineno=5, col_offset=10)
# POSITION: {'line': 5, 'ch': 10} {'line': 7, 'ch': -1}
# Call  BEFORE:  []
#
#  Attribute [<_ast.Call object at 0x10d9cacf8>, <_ast.Load object at 0x10bcad898>]
#
#  Call [<_ast.Attribute object at 0x10d9ca390>, <_ast.Subscript object at 0x10d9ca358>, <_ast.keyword object at 0x10d9ca4a8>]
# NO VISITOR FOR Call
# Attribute(value=Name(id='pd', ctx=Load(), lineno=5, col_offset=10), attr='DataFrame', ctx=Load(), lineno=5, col_offset=10)
# POSITION: {'line': 5, 'ch': 10} {'line': 7, 'ch': -1}
# Call  BEFORE:  []
#
#  Attribute [<_ast.Name object at 0x10d9caa58>, <_ast.Load object at 0x10bcad898>]
#
#  Name [<_ast.Load object at 0x10bcad898>]
# literal |pd|
# END IS: 159 147
# MADE: {'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 20}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}
#
# Call  AFTER:  [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 20}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}] 158
#
# Call  BEFORE:  [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 20}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}]
#
#  Subscript [<_ast.Attribute object at 0x10d9caef0>, <_ast.Index object at 0x10d9ca978>, <_ast.Load object at 0x10bcad898>]
#
#  Attribute [<_ast.Name object at 0x10d9caf98>, <_ast.Load object at 0x10bcad898>]
#
#  Name [<_ast.Load object at 0x10bcad898>]
# literal |data|
# END IS: 168 160
# MADE: {'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}
#
#
#  Index [<_ast.Name object at 0x10d9cada0>]
# Text is: indices], columns = data.keys()).reset_index(drop = True)
# print("Chosen samples of wholesale customers dataset:")
#
#  Name [<_ast.Load object at 0x10bcad898>]
# literal |indices|
# MADE: {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}
#
# MADE: {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}
#
# Call  AFTER:  [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 20}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}] 176
#
# Call  BEFORE:  [{'type': 'Attribute', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 20}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 10}, 'end': {'line': 5, 'ch': 12}, 'literal': 'pd'}, {'syntok': '.'}, {'syntok': 'DataFrame'}]}, {'syntok': '('}, {'type': 'Subscript', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 32}, 'content': [{'type': 'Attribute', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'content': [{'type': 'Name', 'start': {'line': 5, 'ch': 23}, 'end': {'line': 5, 'ch': 27}, 'literal': 'data'}, {'syntok': '.'}, {'syntok': 'loc'}]}, {'type': 'Index', 'start': {'line': 5, 'ch': 31}, 'end': {'line': 5, 'ch': 32}, 'content': [{'syntok': '['}, {'type': 'Name', 'start': {'line': 5, 'ch': 32}, 'end': {'line': 5, 'ch': 39}, 'literal': 'indices'}, {'syntok': ']'}]}]}, {'syntok': ','}, {'syntok': ' '}]
#
#  keyword [<_ast.Call object at 0x10d9ca630>]
# TEXT IS: columns = data.keys()).reset_index(drop = True)
# print("Chosen samples of wholesale customers dataset:")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-1fcd4dbe53e6> in <module>()
#      19 # match parens [] {} () otherwise those can end up in weird places
#      20
# ---> 21 parse(text)
#      22 #print(json.dumps(main(l, tree),  indent=2))
#
# <ipython-input-114-03ef4f937906> in parse(text)
#       2     node = ast.parse(text)
#       3     print(ast.dump(node, True, True))
# ----> 4     print("\n",visit(node, text, 0, len(text), None))
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#      23     else:
#      24         print("NO VISITOR FOR "+myType)
# ---> 25         return genericVisit(node, text, textStart, textEnd, nextNode)
#      26
#      27
#
# <ipython-input-112-d86c4da4275e> in genericVisit(node, text, textStart, textEnd, nextNode)
#      25                myContent += symbols
#      26             print(myType," BEFORE: ", myContent)
# ---> 27             new_i, childContent = visit(child, text, i, textEnd, nextChild)
#      28             myContent.append(childContent)
#      29             col_offset += (new_i - i) - 1
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#      23     else:
#      24         print("NO VISITOR FOR "+myType)
# ---> 25         return genericVisit(node, text, textStart, textEnd, nextNode)
#      26
#      27
#
# <ipython-input-112-d86c4da4275e> in genericVisit(node, text, textStart, textEnd, nextNode)
#      25                myContent += symbols
#      26             print(myType," BEFORE: ", myContent)
# ---> 27             new_i, childContent = visit(child, text, i, textEnd, nextChild)
#      28             myContent.append(childContent)
#      29             col_offset += (new_i - i) - 1
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#      23     else:
#      24         print("NO VISITOR FOR "+myType)
# ---> 25         return genericVisit(node, text, textStart, textEnd, nextNode)
#      26
#      27
#
# <ipython-input-112-d86c4da4275e> in genericVisit(node, text, textStart, textEnd, nextNode)
#      25                myContent += symbols
#      26             print(myType," BEFORE: ", myContent)
# ---> 27             new_i, childContent = visit(child, text, i, textEnd, nextChild)
#      28             myContent.append(childContent)
#      29             col_offset += (new_i - i) - 1
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#      20
#      21     if myType in visitors:
# ---> 22         return visitors[myType](node, text, textStart, textEnd)
#      23     else:
#      24         print("NO VISITOR FOR "+myType)
#
# <ipython-input-63-21eb1f30acbd> in visitAttribute(node, text, textStart, textEnd)
#       2     myType = type(node).__name__
#       3     myContent = []
# ----> 4     end, value = visit(node.value, text, textStart, textEnd, None)
#       5     myContent.append(value)
#       6     myContent.append({'syntok': '.'})
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#      23     else:
#      24         print("NO VISITOR FOR "+myType)
# ---> 25         return genericVisit(node, text, textStart, textEnd, nextNode)
#      26
#      27
#
# <ipython-input-112-d86c4da4275e> in genericVisit(node, text, textStart, textEnd, nextNode)
#      25                myContent += symbols
#      26             print(myType," BEFORE: ", myContent)
# ---> 27             new_i, childContent = visit(child, text, i, textEnd, nextChild)
#      28             myContent.append(childContent)
#      29             col_offset += (new_i - i) - 1
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#      20
#      21     if myType in visitors:
# ---> 22         return visitors[myType](node, text, textStart, textEnd)
#      23     else:
#      24         print("NO VISITOR FOR "+myType)
#
# <ipython-input-97-74b86839c574> in visitKeyword(node, text, textStart, textEnd)
#       7     myType = type(node).__name__
#       8     myContent = []
# ----> 9     end, arg = visit(node.arg, text, textStart, textEnd, None)
#      10     if(arg):
#      11         myContent.append(arg)
#
# <ipython-input-106-22cf3e2617c4> in visit(node, text, textStart, textEnd, nextNode)
#       2
#       3     # 1. first, figure out if we're dealing with a literal or parent
# ----> 4     children = list(ast.iter_child_nodes(node))
#       5
#       6     # necissary to filter children using findNextChild, since there's some
#
# ~/miniconda/envs/verdant-env/lib/python3.6/ast.py in iter_child_nodes(node)
#     181     and all items of fields that are lists of nodes.
#     182     """
# --> 183     for name, field in iter_fields(node):
#     184         if isinstance(field, AST):
#     185             yield field
#
# ~/miniconda/envs/verdant-env/lib/python3.6/ast.py in iter_fields(node)
#     169     that is present on *node*.
#     170     """
# --> 171     for field in node._fields:
#     172         try:
#     173             yield field, getattr(node, field)
#
# AttributeError: 'str' object has no attribute '_fields'
